# %%
# %pip install kaggle
# %pip install scikit-learn

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('smartphone-uncleaned.csv')

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
numeric_df = df.select_dtypes(include=[np.number])

standardized_df = (numeric_df - numeric_df.mean()) / numeric_df.std()

final_df = df.copy()
final_df[numeric_df.columns] = standardized_df

print("\nStandardized Data:")
print(final_df)

standardized_file_path = 'standardized_data.csv' 
final_df.to_csv(standardized_file_path, index=False)

print(f"\nStandardized data saved to {standardized_file_path}")
# Out:
# Standardized Data:
#                                 model    price    rating  \
# 0                       OnePlus 11 5G  ₹54,999  1.451028
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989  0.370364
# 2               Samsung Galaxy A14 5G  ₹16,499 -0.440134
# 3                Motorola Moto G62 5G  ₹14,999  0.370364
# 4                  Realme 10 Pro Plus  ₹24,999  0.505447
# ...                               ...      ...       ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990  0.640530
# 1016                      Honor X8 5G  ₹14,990 -0.440134
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990  0.910696
# 1018             Motorola Moto G91 5G  ₹19,990  0.235281
# 1019           Samsung Galaxy M52s 5G  ₹24,990 -0.575217
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
numeric_df = df.select_dtypes(include=[np.number])

normalized_df = (numeric_df - numeric_df.min()) / (numeric_df.max() - numeric_df.min())

final_df = df.copy()
final_df[numeric_df.columns] = normalized_df

print("\nNormalized Data:")
print(final_df)

normalized_file_path = 'normalized_data.csv'  
final_df.to_csv(normalized_file_path, index=False)

print(f"\nNormalized data saved to {normalized_file_path}")
# Out:
# Normalized Data:
#                                 model    price    rating  \
# 0                       OnePlus 11 5G  ₹54,999  1.000000
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989  0.724138
# 2               Samsung Galaxy A14 5G  ₹16,499  0.517241
# 3                Motorola Moto G62 5G  ₹14,999  0.724138
# 4                  Realme 10 Pro Plus  ₹24,999  0.758621
# ...                               ...      ...       ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990  0.793103
# 1016                      Honor X8 5G  ₹14,990  0.517241
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990  0.862069
# 1018             Motorola Moto G91 5G  ₹19,990  0.689655
# 1019           Samsung Galaxy M52s 5G  ₹24,990  0.482759
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...
